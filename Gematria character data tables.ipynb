# %% [markdown]
# #Gematria character data tables

# %%
from gematria import char_table, char_table_data

# %%
# Genesis 1:1
phrase = "בראשית ברא אלהים את השמים ואת הארץ"
charsum, wordsum, phrasesum = char_table_data(phrase)

# %%
charsum
# Out:
#     gematria letter transliteration    word
# 0          2      ב               b  בראשית
# 1        200      ר               r  בראשית
# 2          1      א               a  בראשית
# 3        300      ש               s  בראשית
# 4         10      י               i  בראשית
# 5        400      ת               t  בראשית
# 6          2      ב               b     ברא
# 7        200      ר               r     ברא
# 8          1      א               a     ברא
# 9          1      א               a   אלהים
# 10        30      ל               l   אלהים
# 11         5      ה               e   אלהים
# 12        10      י               i   אלהים
# 13       600      ם               M   אלהים
# 14         1      א               a      את
# 15       400      ת               t      את
# 16         5      ה               e   השמים
# 17       300      ש               s   השמים
# 18        40      מ               m   השמים
# 19        10      י               i   השמים
# ...

# %%
wordsum
# Out:
#         gematria  characters  digital_sum  digital_root
# word
# אלהים        646           5           16             7
# את           401           2            5             5
# ברא          203           3            5             5
# בראשית       913           6           13             4
# הארץ        1106           4            8             8
# השמים        955           5           19             1
# ואת          407           3           11             2

# %%
phrasesum
# Out:
#    characters  digital_root  digital_sum  gematria  \
# 0          28             5           14      4631
#
#                                phrase
# 0  בראשית ברא אלהים את השמים ואת הארץ

# %%
char_table(phrase)
# Out:
# <table class="char-table"><caption>בראשית ברא אלהים את השמים ואת הארץ</caption><thead><tr><th>ב</th><th>ר</th><th>א</th><th>ש</th><th>י</th><th>ת</th><th>&nbsp;</th><th>&nbsp;</th><th>ב</th><th>ר</th><th>א</th><th>&nbsp;</th><th>&nbsp;</th><th>א</th><th>ל</th><th>ה</th><th>י</th><th>ם</th><th>&nbsp;</th><th>&nbsp;</th><th>א</th><th>ת</th><th>&nbsp;</th><th>&nbsp;</th><th>ה</th><th>ש</th><th>מ</th><th>י</th><th>ם</th><th>&nbsp;</th><th>&nbsp;</th><th>ו</th><th>א</th><th>ת</th><th>&nbsp;</th><th>&nbsp;</th><th>ה</th><th>א</th><th>ר</th><th>ץ</th></tr></thead><tfoot><tr><td colspan="6">913 <sub>4</sub></td><td/><td/><td colspan="3">203 <sub>5</sub></td><td/><td/><td colspan="5">646 <sub>7</sub></td><td/><td/><td colspan="2">401 <sub>5</sub></td><td/><td/><td colspan="5">955 <sub>1</sub></td><td/><td/><td colspan="3">407 <sub>2</sub></td><td/><td/><td colspan="4">1106 <sub>8</sub></td></tr><tr><td colspan="41" style="border-top: solid 1px #ddd">4631 <sub>14 / 5</sub></td></tr></tfoot><tb
# ...

# %%
from IPython.core.display import HTML
with open('gematria.css') as f:
    css = f.read()
HTML('<style>%s</style>' % css)
# Out:
# <style>/* notebook unstylings */
#
# .rendered_html table,
# .rendered_html tr,
# .rendered_html th,
# .rendered_html td {
#     border: 0
# }
#
# /* general table styles */
#
# table {
#     color: black;
#     border: 0;
#     margin: 1.5em auto;
#     border-bottom: 1px solid #999;
#     border-collapse: collapse;
#     -webkit-border-top-left-radius: 8px;
#     -webkit-border-top-right-radius: 8px;
#     -moz-border-radius: 8px 8px 0 0;
#     border-radius: 8px 8px 0 0;
#     background: #444;
# }
# table caption {
#     margin-bottom: .75em;
#     text-align: center;
#     font-style: italic;
# }
# table td {
#     -moz-transition: background 0.2s linear;
#     -o-transition: background 0.2s linear;
#     transition: background 0.2s linear;
#     white-space: nowrap;
#     border-top: 1px solid #eee;
#     border-left: 1px solid #eee;
#     padding: 0.4em 0.8em;
#     background: #fff;
# }
# table tfoot,
# table tbody {
#     outline-offset: -1px;
#     outline: 1px solid #ccc;
# ...

# %% [markdown]
# ## The [MIT](http://choosealicense.com/licenses/mit/) License
#
# Copyright (c) 2015 Marko Manninen
